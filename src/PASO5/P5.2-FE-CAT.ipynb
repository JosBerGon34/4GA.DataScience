# %%
import pandas as pd
import numpy as np, random

# %%
df = pd.read_csv('C:/Users/Josue/4GA.Datascience/4GA.DataScience/data/processed/presplit/dfmodel.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62664 entries, 0 to 62663
# Data columns (total 51 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cntry                           62664 non-null  object
#  1   pplfair                         62664 non-null  float64
#  2   pplhlp                          62664 non-null  float64
#  3   ppltrst                         62664 non-null  float64
#  4   lrscale                         62664 non-null  float64
#  5   polintr                         62664 non-null  float64
#  6   stfdem                          62664 non-null  float64
#  7   stfeco                          62664 non-null  float64
#  8   stfgov                          62664 non-null  float64
#  9   trstep                          62664 non-null  float64
#  10  trstlgl                         62664 non-null  float64
#  11  trstplc                         62664 non-null  float64
#  12  trstplt                         62664 non-null  float64
#  13  trstprl                         62664 non-null  float64
#  14  trstprt                         62664 non-null  float64
#  15  trtsci_pnd                      62664 non-null  float64
#  16  imbgeco                         62664 non-null  float64
#  17  imwbcnt                         62664 non-null  float64
#  18  happy                           62664 non-null  float64
#  19  rlgdgr                          62664 non-null  float64
#  20  cntgrp_fc                       62664 non-null  int64
#  21  lw_pnd                          62664 non-null  float64
#  22  cnt_fc                          62664 non-null  int64
#  23  rel3fc                          62664 non-null  int64
#  24  happyfc                         62664 non-null  int64
#  25  confianza_promedio              62664 non-null  float64
#  26  confianza_promedio_factorizada  62664 non-null  int64
#  27  satisf_media                    62664 non-null  float64
#  28  satisf_media_factorizada        62664 non-null  int64
#  29  pintfc                          62664 non-null  int64
#  30  ppl                             62664 non-null  float64
#  31  ppl_fc                          62664 non-null  int64
#  32  lrscale_fc                      62664 non-null  int64
#  33  lrscale2_fc                     62664 non-null  int64
#  34  lrfc3d                          62664 non-null  int64
#  35  relbin                          62664 non-null  int64
#  36  sm3d                            62664 non-null  int64
#  37  sm4d                            62664 non-null  int64
#  38  lr4d                            62664 non-null  int64
#  39  confM4d                         62664 non-null  int64
#  40  pplfair3d                       62664 non-null  int64
#  41  pplhlp3d                        62664 non-null  int64
#  42  ppltrst3d                       62664 non-null  int64
#  43  stfdem3d                        62664 non-null  int64
#  44  stfeco3d                        62664 non-null  object
#  45  stfgov3d                        62664 non-null  int64
#  46  trstep3d                        62664 non-null  int64
#  47  trstlgl3d                       62664 non-null  object
#  48  trstplc2fc                      62664 non-null  int64
#  49  trstplt2fc                      62664 non-null  int64
#  50  trstprl3d                       62664 non-null  int64
# dtypes: float64(23), int64(25), object(3)
# memory usage: 24.4+ MB

# %%
print(df.columns)

del df['cntry']
# Out:
# Index(['cntry', 'pplfair', 'pplhlp', 'ppltrst', 'lrscale', 'polintr', 'stfdem',
#        'stfeco', 'stfgov', 'trstep', 'trstlgl', 'trstplc', 'trstplt',
#        'trstprl', 'trstprt', 'trtsci_pnd', 'imbgeco', 'imwbcnt', 'happy',
#        'rlgdgr', 'cntgrp_fc', 'lw_pnd', 'cnt_fc', 'rel3fc', 'happyfc',
#        'confianza_promedio', 'confianza_promedio_factorizada', 'satisf_media',
#        'satisf_media_factorizada', 'pintfc', 'ppl', 'ppl_fc', 'lrscale_fc',
#        'lrscale2_fc', 'lrfc3d', 'relbin', 'sm3d', 'sm4d', 'lr4d', 'confM4d',
#        'pplfair3d', 'pplhlp3d', 'ppltrst3d', 'stfdem3d', 'stfeco3d',
#        'stfgov3d', 'trstep3d', 'trstlgl3d', 'trstplc2fc', 'trstplt2fc',
#        'trstprl3d'],
#       dtype='object')

# %%
del_cols=['confianza_promedio','satisf_media','ppl','cntry', 'pplfair', 'pplhlp', 'ppltrst', 'lrscale', 'polintr', 'stfdem',
       'stfeco', 'stfgov', 'trstep', 'trstlgl', 'trstplc', 'trstplt',
       'trstprl', 'trstprt', 'trtsci_pnd']

# %%
import pandas as pd

columnas_a_convertir = ['pplfair', 'pplhlp', 'ppltrst', 'lrscale', 'polintr', 'stfdem',
       'stfeco', 'stfgov', 'trstep', 'trstlgl', 'trstplc', 'trstplt',
       'trstprl', 'trstprt', 'trtsci_pnd', 'imbgeco', 'imwbcnt', 'happy',
       'rlgdgr', 'cntgrp_fc', 'lw_pnd', 'cnt_fc']


for columna in columnas_a_convertir:
    try:
        df[columna] = df[columna].astype('int64')
    except ValueError as e:
        print(f"Error al convertir la columna '{columna}' a enteros: {e}")
    except KeyError as e:
        print(f"La columna '{columna}' no existe en el DataFrame: {e}")


print(df.dtypes)
# Out:
# pplfair                             int64
# pplhlp                              int64
# ppltrst                             int64
# lrscale                             int64
# polintr                             int64
# stfdem                              int64
# stfeco                              int64
# stfgov                              int64
# trstep                              int64
# trstlgl                             int64
# trstplc                             int64
# trstplt                             int64
# trstprl                             int64
# trstprt                             int64
# trtsci_pnd                          int64
# imbgeco                             int64
# imwbcnt                             int64
# happy                               int64
# rlgdgr                              int64
# cntgrp_fc                           int64
# lw_pnd                              int64
# cnt_fc                              int64
# rel3fc                              int64
# happyfc                             int64
# confianza_promedio                float64
# confianza_promedio_factorizada      int64
# satisf_media                      float64
# satisf_media_factorizada            int64
# pintfc                              int64
# ppl                               float64
# ppl_fc                              int64
# lrscale_fc                          int64
# lrscale2_fc                         int64
# lrfc3d                              int64
# relbin                              int64
# sm3d                                int64
# sm4d                                int64
# lr4d                                int64
# confM4d                             int64
# pplfair3d                           int64
# pplhlp3d                            int64
# ppltrst3d                           int64
# stfdem3d                            int64
# stfeco3d                           object
# stfgov3d                            int64
# trstep3d                            int64
# trstlgl3d                          object
# trstplc2fc                          int64
# trstplt2fc                          int64
# trstprl3d                           int64
# dtype: object

# %%
import pandas as pd
map0123 = {
    1: 0,
    2: 1,
    3: 2,
    4: 3,
}
df['polintr'] = df['polintr'].map(map0123).astype(int)
print(df['polintr'].value_counts())
# Out:
# polintr
# 1    22802
# 2    22761
# 3    10542
# 0     6559
# Name: count, dtype: int64

# %%
import pandas as pd
map01234 = {
    1: 0,
    2: 1,
    3: 2,
    4: 3,
    5: 4,
}

df['lw_pnd'] = df['lw_pnd'].map(map01234).astype(int)
print(df['lw_pnd'].value_counts())
# Out:
# lw_pnd
# 1    27001
# 0    20871
# 2     9178
# 3     4961
# 4      653
# Name: count, dtype: int64
