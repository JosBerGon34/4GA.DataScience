# %%
from IPython.display import Image, display

image_path = '../data/raw/proof.png'  # Reemplaza con la ruta de tu imagen
display(Image(filename=image_path))

# %% [markdown]
# A la hora de ejecutarlo en localhost no hay ningun problema porque hemos ajustado todas las versiones de las dependencias para pyhton 3.10.
# -------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Para que funcione importando el repositorio de github a nuestra pagina de streamlit.io, debemos reentrenar el modelo con sckikit-learn 1.3.2
# ademas instalar todas las dependencias compatibles con pyton 3.12.9 que es la version que utiliza streamlit.
# Los requeriments siempre se han de ordenar para que la instalacion no tenga problemas entre dependencias,
# la recomendacion mia es instalarlos en orden de jerarquia inversa.
# -------------------------------------------------------------------------------------------------------------------------------------------
