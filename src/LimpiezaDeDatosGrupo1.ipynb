# %%
import pandas as pd

# %%
df_media = pd.read_csv('C:/Users/Josue/4GA.Datascience/4GA.DataScience/data/raw/EspIta.csv')

# %%
#Eliminamos columnas del df que no interesen
columnas_a_eliminar = ['name', 'essround', 'edition', 'proddate', 'idno', 'dweight', 'pspwght', 'pweight', 'anweight', 'prob', 'stratum', 'psu']
df_media.drop(columnas_a_eliminar, axis=1, inplace=True)

# %%
#Obtenemos una lista con los nombres de las columnas restantes.
nombres_columnas = df_media.columns.tolist()
print(nombres_columnas)
# Out:
# ['cntry', 'pplfair', 'pplhlp', 'ppltrst', 'lrscale', 'polintr', 'stfdem', 'stfeco', 'stfgov', 'trstep', 'trstlgl', 'trstplc', 'trstplt', 'trstprl', 'trstprt', 'trstsci', 'imbgeco', 'imwbcnt', 'happy', 'rlgdgr']

# %%
#Obtenemos una lista con los paises de las muestras de las filas.
valores_unicos_cntry = df_media['cntry'].unique()
print(valores_unicos_cntry)
# Out:
# ['ES' 'IT' 'PT' 'HR']

# %%
#Guardamos en un dataframe nuestra tabla para asignar grupo y valores clave de la columna cntry.
import sqlite3
import pandas as pd


db_path = 'C:/Users/Josue/4GA.Datascience/4GA.DataScience/src/EcoUE.db'
try:
    conn = sqlite3.connect(db_path)
    query = "SELECT * FROM ecoeu"
    df_ecoeu = pd.read_sql_query(query, conn)
    print(df_ecoeu)
except sqlite3.Error as e:
    print(f"Error al conectar o consultar la base de datos: {e}")

finally:
    
    if conn:
        conn.close()
# Out:
#            cntry       PIB  Inflation    sma       cntrycat  color  \
# 0       Alemania   54343.2        5.9  60867           Rico  green
# 1        Austria   56033.6        7.8  57082           Rico  green
# 2        Bélgica   54700.9        4.0  59285           Rico  green
# 3         Chipre   36551.4        3.5  26689  Media Europea   blue
# 4        Croacia   21865.5        7.9  17714  Media Europea   blue
# 5      Eslovenia   32610.1        7.4  26667  Media Europea   blue
# 6         España   33509.0        3.5  30237  Media Europea   blue
# 7        Estonia   30133.3        9.2  21595  Media Europea   blue
# 8      Finlandia   52925.7        6.3  53310           Rico  green
# 9        Francia   44690.9        4.9  43438  Media Europea   blue
# 10        Grecia   23400.7        3.5  23536  Media Europea   blue
# 11       Irlanda  103887.8        6.3  59899           Rico  green
# 12        Italia   39003.3        5.6  33492  Media Europea   blue
# 13       Letonia   22502.8        8.9  18559  Media Europea   blue
# 14      Lituania   27786.0        9.1  23409  Media Europea   blue
# 15    Luxemburgo  128678.2        3.7  73418           Rico  green
# 16         Malta   40395.8        5.1  27232  Media Europea   blue
# 17  Países Bajos   64572.0        3.8  62281           Rico  green
# 18      Portugal   27331.2        4.3  23714  Media Europea   blue
# 19    Eslovaquia   24491.4       10.5  16835          Pobre    red
# 20       Hungría   22141.0       17.1  18730          Pobre    red
#
#     cntrycat_factorizado
# 0                      0
# 1                      0
# 2                      0
# 3                      1
# 4                      1
# 5                      1
# 6                      1
# 7                      1
# 8                      0
# 9                      1
# 10                     1
# 11                     0
# 12                     1
# 13                     1
# 14                     1
# 15                     0
# 16                     1
# 17                     0
# 18                     1
# 19                     2
# 20                     2

# %%
cntrymap= {
    'ES':'España',
    'IT':'Italia',
    'PT':'Portugal',
    'HR':'Croacia',
}

# %%
df_media['cntry'] = df_media['cntry'].map(cntrymap)

# %%
df_media = pd.merge(df_media, df_ecoeu[['cntry', 'cntrycat_factorizado']], on='cntry', how='left')

# %%
print(df_media[['cntry', 'cntrycat_factorizado']])
# Out:
#           cntry  cntrycat_factorizado
# 0        España                     1
# 1        España                     1
# 2        España                     1
# 3        España                     1
# 4        España                     1
# ...         ...                   ...
# 61686  Portugal                     1
# 61687  Portugal                     1
# 61688  Portugal                     1
# 61689  Portugal                     1
# 61690  Portugal                     1
#
# [61691 rows x 2 columns]

# %%
df_media.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61691 entries, 0 to 61690
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cntry                 61691 non-null  object
#  1   pplfair               61691 non-null  int64
#  2   pplhlp                61691 non-null  int64
#  3   ppltrst               61691 non-null  int64
#  4   lrscale               61691 non-null  int64
#  5   polintr               61691 non-null  int64
#  6   stfdem                61691 non-null  int64
#  7   stfeco                61691 non-null  int64
#  8   stfgov                61691 non-null  int64
#  9   trstep                61691 non-null  int64
#  10  trstlgl               61691 non-null  int64
#  11  trstplc               61691 non-null  int64
#  12  trstplt               61691 non-null  int64
#  13  trstprl               61691 non-null  int64
#  14  trstprt               57244 non-null  float64
#  15  trstsci               8353 non-null   float64
#  16  imbgeco               61691 non-null  int64
#  17  imwbcnt               61691 non-null  int64
#  18  happy                 61691 non-null  int64
#  19  rlgdgr                61691 non-null  int64
#  20  cntrycat_factorizado  61691 non-null  int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 9.9+ MB

# %%
#Eliminamos los valores nulos de las columnas, que hacen referencia a que el encuestado no ha querido responder. valores 77,88,99
import pandas as pd
import numpy as np

def delnulos(df):

    columnas_a_limpiar = ['pplfair','pplhlp', 'ppltrst', 'lrscale', 'stfdem','stfeco','stfgov', 'trstep', 'trstlgl', 'trstplc', 'trstplt', 'trstprl', 'trstprt','trstsci','imbgeco','imwbcnt','happy','rlgdgr']
    for columna in columnas_a_limpiar:
        if columna in df.columns:
            df[columna] = np.where(df[columna] > 70, np.nan, df[columna])
            df.dropna(subset=[columna], inplace=True)
    col_v2 = ['polintr']
    for col in col_v2:
        if col in df.columns:
            df[col] = np.where(df[col] > 4, np.nan, df[col])
            df.dropna(subset=[col], inplace=True)
    return df

delnulos(df_media)
print(df_media.isnull().sum())
# Out:
# "#Eliminamos los valores nulos de las columnas, que hacen referencia a que el encuestado no ha querido responder. valores 77,88,99\nimport pandas as pd\nimport numpy as np\n\ndef delnulos(df):\n\n    columnas_a_limpiar = ['pplfair','pplhlp', 'ppltrst', 'lrscale', 'stfdem','stfeco','stfgov', 'trstep', 'trstlgl', 'trstplc', 'trstplt', 'trstprl', 'trstprt','trstsci','imbgeco','imwbcnt','happy','rlgdgr']\n    for columna in columnas_a_limpiar:\n        if columna in df.columns:\n            df[columna] = np.where(df[columna] > 70, np.nan, df[columna])\n            df.dropna(subset=[columna], inplace=True)\n    col_v2 = ['polintr']\n    for col in col_v2:\n        if col in df.columns:\n            df[col] = np.where(df[col] > 4, np.nan, df[col])\n            df.dropna(subset=[col], inplace=True)\n    return df\n\ndelnulos(df_media)\nprint(df_media.isnull().sum())"

# %%
import pandas as pd
import numpy as np

dataspa = {
    'lawobey': {
        1: 0.0222,
        2: 0.435,
        3: 0.23,
        4: 0.094,
        5: 0.02,
    },
    'trstsci': {
        0: 0.011,
        1: 0.003,
        2: 0.018,
        3: 0.028,
        4: 0.039,
        5: 0.075,
        6: 0.132,
        7: 0.217,
        8: 0.252,
        9: 0.136,
        10: 0.088,
    }
}

def rngpond(df, dataspa, cntry_value, missing_threshold):

    df_cntry = df[df['cntry'] == cntry_value].copy()  

    for columna, pesos in dataspa.items():
        if columna in df_cntry.columns and df_cntry[columna].isnull().any():
            valores = np.array(list(pesos.keys()))
            pesos_ponderados = np.array(list(pesos.values()))

            
            suma_pesos = np.sum(pesos_ponderados)
            pesos_normalizados = pesos_ponderados / suma_pesos

            for index, row in df_cntry[df_cntry[columna].isnull()].iterrows():
                
                valor_aleatorio = np.random.choice(valores, p=pesos_normalizados)

                
                df_cntry.loc[index, columna] = valor_aleatorio

    
    for columna in df_cntry.columns:
        if df_cntry[columna].isnull().any():
            missing_percentage = df_cntry[columna].isnull().sum() / len(df_cntry)
            if missing_percentage < missing_threshold:
                mode_value = df_cntry[columna].mode()[0]
                df_cntry[columna].fillna(mode_value, inplace=True)

    
    df.loc[df['cntry'] == cntry_value] = df_cntry 


rngpond(df_media, dataspa, 'España', missing_threshold=0.2)  # Ejemplo para España con umbral del 20%
print(df_media[df_media['cntry'] == 'España'].isnull().sum())
# Out:
# cntry                   0
# pplfair                 0
# pplhlp                  0
# ppltrst                 0
# lrscale                 0
# polintr                 0
# stfdem                  0
# stfeco                  0
# stfgov                  0
# trstep                  0
# trstlgl                 0
# trstplc                 0
# trstplt                 0
# trstprl                 0
# trstprt                 0
# trstsci                 0
# imbgeco                 0
# imwbcnt                 0
# happy                   0
# rlgdgr                  0
# cntrycat_factorizado    0
# dtype: int64
# C:\Users\Josue\AppData\Local\Temp\ipykernel_9804\1957085468.py:53: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cntry[columna].fillna(mode_value, inplace=True)

# %%
df_media.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61691 entries, 0 to 61690
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cntry                 61691 non-null  object
#  1   pplfair               61691 non-null  int64
#  2   pplhlp                61691 non-null  int64
#  3   ppltrst               61691 non-null  int64
#  4   lrscale               61691 non-null  int64
#  5   polintr               61691 non-null  int64
#  6   stfdem                61691 non-null  int64
#  7   stfeco                61691 non-null  int64
#  8   stfgov                61691 non-null  int64
#  9   trstep                61691 non-null  int64
#  10  trstlgl               61691 non-null  int64
#  11  trstplc               61691 non-null  int64
#  12  trstplt               61691 non-null  int64
#  13  trstprl               61691 non-null  int64
#  14  trstprt               58973 non-null  float64
#  15  trstsci               27366 non-null  float64
#  16  imbgeco               61691 non-null  int64
#  17  imwbcnt               61691 non-null  int64
#  18  happy                 61691 non-null  int64
#  19  rlgdgr                61691 non-null  int64
#  20  cntrycat_factorizado  61691 non-null  int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 9.9+ MB

# %%
valores_unicos_cntry = df_media['cntry'].unique()
print(valores_unicos_cntry)
# Out:
# ['España' 'Italia' 'Portugal' 'Croacia']

# %%
import pandas as pd
import numpy as np

datacro = {
    'lawobey': {
        1: 0.487,
        2: 0.391,
        3: 0.082,
        4: 0.028,
        5: 0.011,
    },
    'trstsci': {
        0: 0.038,
        1: 0.017,
        2: 0.031,
        3: 0.05,
        4: 0.057,
        5: 0.144,
        6: 0.089,
        7: 0.158,
        8: 0.182,
        9: 0.116,
        10: 0.118,
    }
}
rngpond(df_media, datacro, 'Croacia', missing_threshold=0.2) 
print(df_media[df_media['cntry'] == 'Croacia'].isnull().sum())
# Out:
# cntry                   0
# pplfair                 0
# pplhlp                  0
# ppltrst                 0
# lrscale                 0
# polintr                 0
# stfdem                  0
# stfeco                  0
# stfgov                  0
# trstep                  0
# trstlgl                 0
# trstplc                 0
# trstplt                 0
# trstprl                 0
# trstprt                 0
# trstsci                 0
# imbgeco                 0
# imwbcnt                 0
# happy                   0
# rlgdgr                  0
# cntrycat_factorizado    0
# dtype: int64

# %%
print(valores_unicos_cntry)
df_media.info()
# Out:
# ['España' 'Italia' 'Portugal' 'Croacia']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61691 entries, 0 to 61690
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cntry                 61691 non-null  object
#  1   pplfair               61691 non-null  int64
#  2   pplhlp                61691 non-null  int64
#  3   ppltrst               61691 non-null  int64
#  4   lrscale               61691 non-null  int64
#  5   polintr               61691 non-null  int64
#  6   stfdem                61691 non-null  int64
#  7   stfeco                61691 non-null  int64
#  8   stfgov                61691 non-null  int64
#  9   trstep                61691 non-null  int64
#  10  trstlgl               61691 non-null  int64
#  11  trstplc               61691 non-null  int64
#  12  trstplt               61691 non-null  int64
#  13  trstprl               61691 non-null  int64
#  14  trstprt               58973 non-null  float64
#  15  trstsci               33872 non-null  float64
#  16  imbgeco               61691 non-null  int64
#  17  imwbcnt               61691 non-null  int64
#  18  happy                 61691 non-null  int64
#  19  rlgdgr                61691 non-null  int64
#  20  cntrycat_factorizado  61691 non-null  int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 9.9+ MB

# %%
import pandas as pd
import numpy as np

dataita= {
    'lawobey': {
        1: 0.508,
        2: 0.394,
        3: 0.073,
        4: 0.019,
        5: 0.006,
    },
    'trstsci': {
        0: 0.01,
        1: 0.003,
        2: 0.018,
        3: 0.029,
        4: 0.038,
        5: 0.073,
        6: 0.135,
        7: 0.217,
        8: 0.25,
        9: 0.134,
        10: 0.092,
    }
}
rngpond(df_media, dataita, 'Italia', missing_threshold=0.2) 
print(df_media[df_media['cntry'] == 'Italia'].isnull().sum())
# Out:
# cntry                   0
# pplfair                 0
# pplhlp                  0
# ppltrst                 0
# lrscale                 0
# polintr                 0
# stfdem                  0
# stfeco                  0
# stfgov                  0
# trstep                  0
# trstlgl                 0
# trstplc                 0
# trstplt                 0
# trstprl                 0
# trstprt                 0
# trstsci                 0
# imbgeco                 0
# imwbcnt                 0
# happy                   0
# rlgdgr                  0
# cntrycat_factorizado    0
# dtype: int64
# C:\Users\Josue\AppData\Local\Temp\ipykernel_9804\1957085468.py:53: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cntry[columna].fillna(mode_value, inplace=True)

# %%
print(valores_unicos_cntry)
df_media.info()
# Out:
# ['España' 'Italia' 'Portugal' 'Croacia']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61691 entries, 0 to 61690
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cntry                 61691 non-null  object
#  1   pplfair               61691 non-null  int64
#  2   pplhlp                61691 non-null  int64
#  3   ppltrst               61691 non-null  int64
#  4   lrscale               61691 non-null  int64
#  5   polintr               61691 non-null  int64
#  6   stfdem                61691 non-null  int64
#  7   stfeco                61691 non-null  int64
#  8   stfgov                61691 non-null  int64
#  9   trstep                61691 non-null  int64
#  10  trstlgl               61691 non-null  int64
#  11  trstplc               61691 non-null  int64
#  12  trstplt               61691 non-null  int64
#  13  trstprl               61691 non-null  int64
#  14  trstprt               60180 non-null  float64
#  15  trstsci               44275 non-null  float64
#  16  imbgeco               61691 non-null  int64
#  17  imwbcnt               61691 non-null  int64
#  18  happy                 61691 non-null  int64
#  19  rlgdgr                61691 non-null  int64
#  20  cntrycat_factorizado  61691 non-null  int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 9.9+ MB

# %%
import pandas as pd
import numpy as np

datapor= {
    'lawobey': {
        1: 0.194,
        2: 0.489,
        3: 0.214,
        4: 0.094,
        5: 0.009,
    },
    'trstsci': {
        0: 0.011,
        1: 0.004,
        2: 0.007,
        3: 0.014,
        4: 0.025,
        5: 0.114,
        6: 0.082,
        7: 0.145,
        8: 0.285,
        9: 0.166,
        10: 0.147,
    }
}
rngpond(df_media, datapor, 'Portugal', missing_threshold=0.2) 
print(df_media[df_media['cntry'] == 'Portugal'].isnull().sum())
# Out:
# cntry                   0
# pplfair                 0
# pplhlp                  0
# ppltrst                 0
# lrscale                 0
# polintr                 0
# stfdem                  0
# stfeco                  0
# stfgov                  0
# trstep                  0
# trstlgl                 0
# trstplc                 0
# trstplt                 0
# trstprl                 0
# trstprt                 0
# trstsci                 0
# imbgeco                 0
# imwbcnt                 0
# happy                   0
# rlgdgr                  0
# cntrycat_factorizado    0
# dtype: int64
# C:\Users\Josue\AppData\Local\Temp\ipykernel_9804\1957085468.py:53: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cntry[columna].fillna(mode_value, inplace=True)

# %%
df_media.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61691 entries, 0 to 61690
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cntry                 61691 non-null  object
#  1   pplfair               61691 non-null  int64
#  2   pplhlp                61691 non-null  int64
#  3   ppltrst               61691 non-null  int64
#  4   lrscale               61691 non-null  int64
#  5   polintr               61691 non-null  int64
#  6   stfdem                61691 non-null  int64
#  7   stfeco                61691 non-null  int64
#  8   stfgov                61691 non-null  int64
#  9   trstep                61691 non-null  int64
#  10  trstlgl               61691 non-null  int64
#  11  trstplc               61691 non-null  int64
#  12  trstplt               61691 non-null  int64
#  13  trstprl               61691 non-null  int64
#  14  trstprt               61691 non-null  float64
#  15  trstsci               61691 non-null  float64
#  16  imbgeco               61691 non-null  int64
#  17  imwbcnt               61691 non-null  int64
#  18  happy                 61691 non-null  int64
#  19  rlgdgr                61691 non-null  int64
#  20  cntrycat_factorizado  61691 non-null  int64
# dtypes: float64(2), int64(18), object(1)
# memory usage: 9.9+ MB

# %%
#Eliminamos los valores nulos de las columnas, que hacen referencia a que el encuestado no ha querido responder. valores 77,88,99
import pandas as pd
import numpy as np

def delnulos(df):

    columnas_a_limpiar = ['pplfair','pplhlp', 'ppltrst', 'lrscale', 'stfdem','stfeco','stfgov', 'trstep', 'trstlgl', 'trstplc', 'trstplt', 'trstprl', 'trstprt','trstsci','imbgeco','imwbcnt','happy','rlgdgr']
    for columna in columnas_a_limpiar:
        if columna in df.columns:
            df[columna] = np.where(df[columna] > 70, np.nan, df[columna])
            df.dropna(subset=[columna], inplace=True)
    col_v2 = ['polintr']
    for col in col_v2:
        if col in df.columns:
            df[col] = np.where(df[col] > 4, np.nan, df[col])
            df.dropna(subset=[col], inplace=True)
    return df

delnulos(df_media)
print(df_media.isnull().sum())
# Out:
# cntry                   0
# pplfair                 0
# pplhlp                  0
# ppltrst                 0
# lrscale                 0
# polintr                 0
# stfdem                  0
# stfeco                  0
# stfgov                  0
# trstep                  0
# trstlgl                 0
# trstplc                 0
# trstplt                 0
# trstprl                 0
# trstprt                 0
# trstsci                 0
# imbgeco                 0
# imwbcnt                 0
# happy                   0
# rlgdgr                  0
# cntrycat_factorizado    0
# dtype: int64

# %%
df_media.rename(columns={'lawobey': 'lw_pnd', 'trstsci': 'trtsci_pnd','cntrycat_factorizado': 'cntgrp_fc',}, inplace=True)

# %%
df_media.to_csv('C:/Users/Josue/4GA.Datascience/4GA.DataScience/data/raw/UEmedG1.csv',index=False)

# %%
# %reset -f
